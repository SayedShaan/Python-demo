# %%
import pandas as pd
df=pd.read_csv("company-sales.csv")
df.head(3)
# Out:
#    month_number  facecream  facewash  toothpaste  bathingsoap  shampoo  \
# 0             1       2500      1500        5200         9200     1200
# 1             2       2630      1200        5100         6100     2100
# 2             3       2140      1340        4550         9550     3550
#
#    moisturizer  total_units  total_profit
# 0         1500        21100        211000
# 1         1200        18330        183300
# 2         1340        22470        224700

# %%
import matplotlib.pyplot as plt
plt.plot(df.month_number,df.total_profit)
plt.xlabel("Month Number")
plt.ylabel("Total Profit")
plt.title("Company Profit Per Month")
plt.xticks(df.month_number)
plt.yticks([100000,200000,300000,400000,500000])
# Out:
# ([<matplotlib.axis.YTick at 0x1d62e2cf950>,
#   <matplotlib.axis.YTick at 0x1d62f778cb0>,
#   <matplotlib.axis.YTick at 0x1d62f7796d0>,
#   <matplotlib.axis.YTick at 0x1d62f913380>,
#   <matplotlib.axis.YTick at 0x1d62e4287a0>],
#  [Text(0, 100000, '100000'),
#   Text(0, 200000, '200000'),
#   Text(0, 300000, '300000'),
#   Text(0, 400000, '400000'),
#   Text(0, 500000, '500000')])

# %%
ages=[21,25,26,29,30,35,38,41,39,45,9,18,12,55,66,75,78]
import matplotlib.pyplot as plt
plt.hist(ages,bins=10,range=(0,100),histtype="stepfilled",rwidth=1)
plt.ylim(ymax=5,ymin=0)

#step , stepfilled , bar
# Out:
# (0.0, 5.0)

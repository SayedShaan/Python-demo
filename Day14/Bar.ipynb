# %%
data=[45000,15000]
labels=["Female","Male"]

# %%
import matplotlib.pyplot as plt

# %%
plt.bar(labels,data,color=["r","g"])
# Out:
# <BarContainer object of 2 artists>

# %%
plt.barh(labels,data,color=["r","g"])
# Out:
# <BarContainer object of 2 artists>

# %%
hours=[3,8,9,4]
activities=["eat","sleep","work","play"]
import matplotlib.pyplot as plt
plt.pie(hours,labels=activities,colors=["r","y","b","g"],radius = 2.5,
       autopct="%.2f%%")
# Out:
# ([<matplotlib.patches.Wedge at 0x212b835a780>,
# ...
#  [Text(2.5406687144060385, 1.0523794390039969, 'eat'),
#   Text(-0.7117524569320588, 2.6562960000819147, 'sleep'),
#   Text(-1.6740937935956284, -2.181721790294216, 'work'),
#   Text(2.3815699676878577, -1.3749998141844437, 'play')],
#  [Text(1.38581929876693, 0.5740251485476346, '12.50%'),
#   Text(-0.3882286128720321, 1.4488887273174078, '33.33%'),
#   Text(-0.9131420692339791, -1.1900300674332085, '37.50%'),
#   Text(1.299038164193377, -0.7499998986460603, '16.67%')])
